# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df=pd.read_csv("BankCustomers.csv")
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
age=df["Age"]
Salary=df["EstimatedSalary"]
CreditScore=df["CreditScore"]
exited=df["Exited"]
plt.plot(Salary,Salary,c="white",marker='o', mfc="black",ms=10)

# %%
plt.plot(x,y,"r")
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Title")
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig=plt.figure(figsize=(10,5))
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,label="X vs Y",color="red",lw=3,alpha=0.5,ls='--',marker='o',
        markersize=10,markerfacecolor='black',mew=10,mec="black")
ax.legend(loc=0)
ax.set_xlabel("X-Label")
ax.set_ylabel("Y-Label")
ax.set_title("Title")
# ax.set_xlim([0,1]) for more detailed anaylis
# ax.set_ylim([0,2])
fig.savefig("my_pic.png",dpi=1050)
