# %%
# Hangman game
#

# -----------------------------------
# Helper code
# You don't need to understand this helper code,
# but you will have to know how to use the functions
# (so be sure to read the docstrings!)

import random

WORDLIST_FILENAME = "words.txt"

def loadWords():
    """
    Returns a list of valid words. Words are strings of lowercase letters.
    
    Depending on the size of the word list, this function may
    take a while to finish.
    """
    print("Loading word list from file...")
    # inFile: file
    inFile = open(WORDLIST_FILENAME, 'r')
    # line: string
    line = inFile.readline()
    # wordlist: list of strings
    wordlist = line.split()
    print("  ", len(wordlist), "words loaded.")
    return wordlist

def chooseWord(wordlist):
    """
    wordlist (list): list of words (strings)

    Returns a word from wordlist at random
    """
    return random.choice(wordlist)

# end of helper code
# -----------------------------------

# Load the list of words into the variable wordlist
# so that it can be accessed from anywhere in the program
wordlist = loadWords()
secretWord=chooseWord(wordlist)
# lettersGuessed=list(input())



def isWordGuessed(secretWord, lettersGuessed):
    x=[]
    for i in secretWord:
        if i in lettersGuessed:
            x.append(i)
    if len(x)==len(secretWord):
        return "Congratulations, you won!"
    else:
        return print("Sorry, you ran out of guesses. The word was",secretWord)
    
isWordGuessed(secretWord,lettersGuessed)



def getGuessedWord(secretWord, lettersGuessed):
    x=""
    for i in secretWord:
        if i in lettersGuessed:
            x+=(i)
        else:
            x+=("_ ")
    return x
    

getGuessedWord(secretWord,lettersGuessed)


def getAvailableLetters(lettersGuessed):
    let="abcdefghijklmnopqrstuvwxyz"
    newlet=""
    for i in let:
        if i not in lettersGuessed:
            newlet+=i
    return newlet
            

getAvailableLetters(lettersGuessed)


def hangman(secretWord):
    print("Welcome to the game, Hangman!")
    length=len(secretWord)
    print("I am thinking of a word that is "+str(length)+" letters long")
    num_try=8
    lettersGuessed=[]
    for i in range(num_try) :
        print("You have",num_try, "guesses left.")
        print(getAvailableLetters(lettersGuessed))
        guessing=input("Please guess a letter: ")
        if guessing in lettersGuessed:
            while True:
                print("Oops! You've already guessed that letter", getGuessedWord(secretWord, lettersGuessed))
                print("You have",num_try, "guesses left.")
                guessing=input("Please guess a letter: ")
                if guessing not in lettersGuessed:
                    break
        lettersGuessed+=[guessing] 
        if guessing in secretWord:
            print("Good guess: ",getGuessedWord(secretWord, lettersGuessed) )
        if guessing not in secretWord:
            print("Oops! That letter is not in my word: ",getGuessedWord(secretWord, lettersGuessed))
        num_try-=1
    return isWordGuessed(secretWord, lettersGuessed)
hangman(secretWord)





# When you've completed your hangman function, uncomment these two lines
# and run this file to test! (hint: you might want to pick your own
# secretWord while you're testing)

# secretWord = chooseWord(wordlist).lower()
# hangman(secretWord)
# Out:
# Loading word list from file...
#    55909 words loaded.
# Sorry, you ran out of guesses. The word was sturdiness
# Welcome to the game, Hangman!
# I am thinking of a word that is 10 letters long
# You have 8 guesses left.
# abcdefghijklmnopqrstuvwxyz
# Please guess a letter: a
# Oops! That letter is not in my word:  _ _ _ _ _ _ _ _ _ _
# You have 7 guesses left.
# bcdefghijklmnopqrstuvwxyz
# Please guess a letter: v
# Oops! That letter is not in my word:  _ _ _ _ _ _ _ _ _ _
# You have 6 guesses left.
# bcdefghijklmnopqrstuwxyz
# Please guess a letter: r
# Good guess:  _ _ _ r_ _ _ _ _ _
# You have 5 guesses left.
# bcdefghijklmnopqstuwxyz
# Please guess a letter: y
# Oops! That letter is not in my word:  _ _ _ r_ _ _ _ _ _
# You have 4 guesses left.
# bcdefghijklmnopqstuwxz
# Please guess a letter: u
# Good guess:  _ _ ur_ _ _ _ _ _
# You have 3 guesses left.
# bcdefghijklmnopqstwxz
# Please guess a letter: i
# Good guess:  _ _ ur_ i_ _ _ _
# You have 2 guesses left.
# bcdefghjklmnopqstwxz
# Please guess a letter: d
# Good guess:  _ _ urdi_ _ _ _
# You have 1 guesses left.
# bcefghjklmnopqstwxz
# Please guess a letter: a
# Oops! You've already guessed that letter _ _ urdi_ _ _ _
# You have 1 guesses left.
# Please guess a letter: w
# Oops! That letter is not in my word:  _ _ urdi_ _ _ _
# Sorry, you ran out of guesses. The word was sturdiness
